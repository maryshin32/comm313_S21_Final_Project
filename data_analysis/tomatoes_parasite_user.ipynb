# %% [markdown]
# # Scraping Rotten Tomatoes for User Reviews of _Parasite_
#
# In this notebook, I work on scraping, cleaning, and extracting reviews of _Parasite_ from [Rotten Tomatoes](https://www.rottentomatoes.com/m/parasite_2019/reviews?type=verified_audience&intcmp=rt-scorecard_audience-score-reviews). Going through the same process as the one in the `tomatoes_host_user` notebook, I compile these user reviews so I can carry out analysis on them to understand what audience users have said about these movies!

# %%
import requests
from bs4 import BeautifulSoup
import time
import json
from nltk.corpus import stopwords
import random
import re
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from nltk import tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from collections import Counter

# %%
chars_to_strip = '().[]!,"'

# %%
# %run functions.ipynb

# %%
url = 'https://www.rottentomatoes.com/m/parasite_2019/reviews?type=verified_audience&intcmp=rt-scorecard_audience-score-reviews'

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
resp = requests.get(url, headers=headers)

# %%
html = resp.text

# %%
doc = BeautifulSoup(html, 'html.parser')

# %%
reviews = doc.find_all('li', attrs={'class':'audience-reviews__item'})

# %%
len(reviews)
# Out:
# 10

# %%
reviews[9]
# Out:
# <li class="audience-reviews__item" data-qa="review-item">
# <div class="audience-reviews__user-wrap">
# <span class="audience-review__default-image"></span>
# <div class="audience-reviews__name-wrap ">
# <span class="audience-reviews__name" data-qa="review-name">Mickey S</span>
# </div>
# </div>
# <div class="audience-reviews__review-wrap">
# <span class="audience-reviews__score"><span class="star-display" data-qa="star-display"><span class="star-display__filled "></span><span class="star-display__filled "></span><span class="star-display__empty"></span><span class="star-display__empty"></span><span class="star-display__empty"></span></span></span>
# <span class="audience-reviews__verified hidden-md hidden-lg js-verified-review">Verified</span>
# <span class="audience-reviews__verified js-verified-popover hidden-xs hidden-sm" data-container="body" data-placement="bottom" data-toggle="popover" data-trigger="hover" type="button">Verified</span>
# <span class="audience-reviews__duration" data-qa="review-duration">Mar 11, 2020</span>
# <p class="audience-reviews__review js-review-text clamp clamp-8 js-clamp" data-qa="review-text">Wayyy too much unnecessary violence towards the end. Too much graphic violence</p>
# <p class="audience-reviews__review--mobile js-review-text clamp clamp-4 js-clamp" data-qa="review-mobile-text">Wayyy too much unnecessary violence towards the end. Too much graphic violence</p>
# <div class="review-flag-btn__wrapper">
# <button class="js-review-flag-btn review-flag-btn review-flag-btn--right" data-author-id="3b3aecbc-96fc-46bf-8175-7337c37205dd" data-author-realm="Fandango" data-review-id="">Flag this review</button>
# </div>
# </div>
# </li>

# %% [markdown]
# * Credit:
# The code below, used to scrape audience reviews from Rotten Tomatoes, was adapted from: https://stackoverflow.com/questions/62386747/how-to-scrape-rottentomatoes-audience-reviews-using-python

# %%
r = requests.get("https://www.rottentomatoes.com/m/parasite_2019/reviews?type=user")
data = json.loads(re.search('movieReview\s=\s(.*);', r.text).group(1))

movieId = data["movieId"]

def getReviews(endCursor):
    r = requests.get(f"https://www.rottentomatoes.com/napi/movie/{movieId}/reviews/user",
    params = {
        "direction": "next",
        "endCursor": endCursor,
        "startCursor": ""
    })
    return r.json()

reviews = []
result = {}
for i in range(0, 468):
    print(f"[{i}] request review")
    result = getReviews(result["pageInfo"]["endCursor"] if i != 0  else "")
    reviews.extend([t for t in result["reviews"]])
    time.sleep(0.1)

print(f"got {len(reviews)} reviews")
# Out:
# [0] request review
# [1] request review
# [2] request review
# [3] request review
# [4] request review
# [5] request review
# [6] request review
# [7] request review
# [8] request review
# [9] request review
# [10] request review
# [11] request review
# [12] request review
# [13] request review
# [14] request review
# [15] request review
# [16] request review
# [17] request review
# [18] request review
# [19] request review
# [20] request review
# [21] request review
# [22] request review
# [23] request review
# [24] request review
# [25] request review
# [26] request review
# [27] request review
# [28] request review
# [29] request review
# [30] request review
# [31] request review
# [32] request review
# [33] request review
# [34] request review
# [35] request review
# [36] request review
# [37] request review
# [38] request review
# [39] request review
# [40] request review
# [41] request review
# [42] request review
# [43] request review
# [44] request review
# [45] request review
# [46] request review
# [47] request review
# [48] request review
# [49] request review
# [50] request review
# [51] request review
# [52] request review
# [53] request review
# [54] request review
# [55] request review
# [56] request review
# [57] request review
# [58] request review
# [59] request review
# [60] request review
# [61] request review
# [62] request review
# [63] request review
# [64] request review
# [65] request review
# [66] request review
# [67] request review
# [68] request review
# [69] request review
# [70] request review
# [71] request review
# [72] request review
# [73] request review
# [74] request review
# [75] request review
# [76] request review
# [77] request review
# [78] request review
# [79] request review
# [80] request review
# [81] request review
# [82] request review
# [83] request review
# [84] request review
# [85] request review
# [86] request review
# [87] request review
# [88] request review
# [89] request review
# [90] request review
# [91] request review
# [92] request review
# [93] request review
# [94] request review
# [95] request review
# [96] request review
# [97] request review
# [98] request review
# [99] request review
# [100] request review
# [101] request review
# [102] request review
# [103] request review
# [104] request review
# [105] request review
# [106] request review
# [107] request review
# [108] request review
# [109] request review
# [110] request review
# [111] request review
# [112] request review
# [113] request review
# [114] request review
# [115] request review
# [116] request review
# [117] request review
# [118] request review
# [119] request review
# [120] request review
# [121] request review
# [122] request review
# [123] request review
# [124] request review
# [125] request review
# [126] request review
# [127] request review
# [128] request review
# [129] request review
# [130] request review
# [131] request review
# [132] request review
# [133] request review
# [134] request review
# [135] request review
# [136] request review
# [137] request review
# [138] request review
# [139] request review
# [140] request review
# [141] request review
# [142] request review
# [143] request review
# [144] request review
# [145] request review
# [146] request review
# [147] request review
# [148] request review
# [149] request review
# [150] request review
# [151] request review
# [152] request review
# [153] request review
# [154] request review
# [155] request review
# [156] request review
# [157] request review
# [158] request review
# [159] request review
# [160] request review
# [161] request review
# [162] request review
# [163] request review
# [164] request review
# [165] request review
# [166] request review
# [167] request review
# [168] request review
# [169] request review
# [170] request review
# [171] request review
# [172] request review
# [173] request review
# [174] request review
# [175] request review
# [176] request review
# [177] request review
# [178] request review
# [179] request review
# [180] request review
# [181] request review
# [182] request review
# [183] request review
# [184] request review
# [185] request review
# [186] request review
# [187] request review
# [188] request review
# [189] request review
# [190] request review
# [191] request review
# [192] request review
# [193] request review
# [194] request review
# [195] request review
# [196] request review
# [197] request review
# [198] request review
# [199] request review
# [200] request review
# [201] request review
# [202] request review
# [203] request review
# [204] request review
# [205] request review
# [206] request review
# [207] request review
# [208] request review
# [209] request review
# [210] request review
# [211] request review
# [212] request review
# [213] request review
# [214] request review
# [215] request review
# [216] request review
# [217] request review
# [218] request review
# [219] request review
# [220] request review
# [221] request review
# [222] request review
# [223] request review
# [224] request review
# [225] request review
# [226] request review
# [227] request review
# [228] request review
# [229] request review
# [230] request review
# [231] request review
# [232] request review
# [233] request review
# [234] request review
# [235] request review
# [236] request review
# [237] request review
# [238] request review
# [239] request review
# [240] request review
# [241] request review
# [242] request review
# [243] request review
# [244] request review
# [245] request review
# [246] request review
# [247] request review
# [248] request review
# [249] request review
# [250] request review
# [251] request review
# [252] request review
# [253] request review
# [254] request review
# [255] request review
# [256] request review
# [257] request review
# [258] request review
# [259] request review
# [260] request review
# [261] request review
# [262] request review
# [263] request review
# [264] request review
# [265] request review
# [266] request review
# [267] request review
# [268] request review
# [269] request review
# [270] request review
# [271] request review
# [272] request review
# [273] request review
# [274] request review
# [275] request review
# [276] request review
# [277] request review
# [278] request review
# [279] request review
# [280] request review
# [281] request review
# [282] request review
# [283] request review
# [284] request review
# [285] request review
# [286] request review
# [287] request review
# [288] request review
# [289] request review
# [290] request review
# [291] request review
# [292] request review
# [293] request review
# [294] request review
# [295] request review
# [296] request review
# [297] request review
# [298] request review
# [299] request review
# [300] request review
# [301] request review
# [302] request review
# [303] request review
# [304] request review
# [305] request review
# [306] request review
# [307] request review
# [308] request review
# [309] request review
# [310] request review
# [311] request review
# [312] request review
# [313] request review
# [314] request review
# [315] request review
# [316] request review
# [317] request review
# [318] request review
# [319] request review
# [320] request review
# [321] request review
# [322] request review
# [323] request review
# [324] request review
# [325] request review
# [326] request review
# [327] request review
# [328] request review
# [329] request review
# [330] request review
# [331] request review
# [332] request review
# [333] request review
# [334] request review
# [335] request review
# [336] request review
# [337] request review
# [338] request review
# [339] request review
# [340] request review
# [341] request review
# [342] request review
# [343] request review
# [344] request review
# [345] request review
# [346] request review
# [347] request review
# [348] request review
# [349] request review
# [350] request review
# [351] request review
# [352] request review
# [353] request review
# [354] request review
# [355] request review
# [356] request review
# [357] request review
# [358] request review
# [359] request review
# [360] request review
# [361] request review
# [362] request review
# [363] request review
# [364] request review
# [365] request review
# [366] request review
# [367] request review
# [368] request review
# [369] request review
# [370] request review
# [371] request review
# [372] request review
# [373] request review
# [374] request review
# [375] request review
# [376] request review
# [377] request review
# [378] request review
# [379] request review
# [380] request review
# [381] request review
# [382] request review
# [383] request review
# [384] request review
# [385] request review
# [386] request review
# [387] request review
# [388] request review
# [389] request review
# [390] request review
# [391] request review
# [392] request review
# [393] request review
# [394] request review
# [395] request review
# [396] request review
# [397] request review
# [398] request review
# [399] request review
# [400] request review
# [401] request review
# [402] request review
# [403] request review
# [404] request review
# [405] request review
# [406] request review
# [407] request review
# [408] request review
# [409] request review
# [410] request review
# [411] request review
# [412] request review
# [413] request review
# [414] request review
# [415] request review
# [416] request review
# [417] request review
# [418] request review
# [419] request review
# [420] request review
# [421] request review
# [422] request review
# [423] request review
# [424] request review
# [425] request review
# [426] request review
# [427] request review
# [428] request review
# [429] request review
# [430] request review
# [431] request review
# [432] request review
# [433] request review
# [434] request review
# [435] request review
# [436] request review
# [437] request review
# [438] request review
# [439] request review
# [440] request review
# [441] request review
# [442] request review
# [443] request review
# [444] request review
# [445] request review
# [446] request review
# [447] request review
# [448] request review
# [449] request review
# [450] request review
# [451] request review
# [452] request review
# [453] request review
# [454] request review
# [455] request review
# [456] request review
# [457] request review
# [458] request review
# [459] request review
# [460] request review
# [461] request review
# [462] request review
# [463] request review
# [464] request review
# [465] request review
# [466] request review
# [467] request review
# got 4672 reviews

# %%
len(reviews)
# Out:
# 4672

# %%
reviews[:8]
# Out:
# [{'createDate': '2021-05-01T18:51:44.935Z',
#   'displayImageUrl': None,
#   'displayName': 'Sarah K',
#   'hasProfanity': False,
#   'hasSpoilers': False,
#   'isSuperReviewer': False,
#   'isVerified': False,
#   'rating': 'STAR_5',
#   'review': "Watch it!!!!!!! I don't need to say a word, just trust me.",
#   'score': 5,
#   'timeFromCreation': '3h ago',
#   'updateDate': '2021-05-01T18:51:45.025Z',
#   'user': {'accountLink': '/user/id/904364501',
#    'displayName': 'Sarah K',
#    'realm': 'RT',
#    'userId': '904364501'}},
#  {'createDate': '2021-04-29T00:36:11.591Z',
#   'displayImageUrl': None,
#   'displayName': 'Keelan M',
#   'hasProfanity': False,
#   'hasSpoilers': False,
#   'isSuperReviewer': False,
#   'isVerified': False,
#   'rating': 'STAR_5',
#   'review': 'unlike the justice league the snyder cut the parasite is not 4 hours long and actually good and balances its comedy, drama and horror elements with razor precision therefore it is pretentious therefore it is not kino',
#   'score': 5,
#   'timeFromCreation': '3d ago',
#   'updateDate': '2021-04-29T15:52:54.519Z',
#   'user': {'accountLink': '/user/id/953017857',
#    'displayName': 'Keelan M',
#    'realm': 'RT',
#    'userId': '953017857'}},
#  {'createDate': '2021-04-28T19:17:32.496Z',
#   'displayImageUrl': None,
#   'displayName': 'Korah K',
#   'hasProfanity': False,
#   'hasSpoilers': False,
#   'isSuperReviewer': False,
#   'isVerified': False,
#   'rating': 'STAR_5',
#   'review': "One of the best films I've ever seen in my life, couldn't have been executed better.\nBrilliant actors, amazing script, great twist, just marvelous!",
#   'score': 5,
#   'timeFromCreation': '3d ago',
#   'updateDate': '2021-04-28T19:17:32.154Z',
#   'user': {'accountLink': '/user/id/977854363',
#    'displayName': 'Korah K',
#    'realm': 'RT',
#    'userId': '977854363'}},
#  {'createDate': '2021-04-28T08:36:22.108Z',
#   'displayImageUrl': None,
#   'displayName': 'Lluis G',
#   'hasProfanity': False,
#   'hasSpoilers': False,
#   'isSuperReviewer': False,
#   'isVerified': False,
#   'rating': 'STAR_5',
#   'review': '100% fresh baby no puedes darle menos a esto',
#   'score': 5,
#   'timeFromCreation': '4d ago',
#   'updateDate': '2021-04-28T08:36:21.894Z',
#   'user': {'accountLink': '/user/id/979119882',
#    'displayName': 'Lluis G',
#    'realm': 'RT',
#    'userId': '979119882'}},
#  {'createDate': '2021-04-27T19:32:08.915Z',
#   'displayImageUrl': None,
#   'displayName': 'Isabelle N',
#   'hasProfanity': False,
#   'hasSpoilers': False,
#   'isSuperReviewer': False,
#   'isVerified': False,
#   'rating': 'STAR_5',
#   'review': "This movie is a masterpiece in all senses. Parasite portrays the intimate true about the social classes. The movement of characters show how the difference between classes in life occurs. The colors and the photography speak without using words. The script is amazing, the film is of elegant suspense that doesn't show itself and makes the audience scream Wow! every moment. I think is a good movie to explain the social issues in a decadent society, which only cares about not losing its position of power.",
#   'score': 5,
#   'timeFromCreation': '4d ago',
#   'updateDate': '2021-04-27T19:32:09.467Z',
#   'user': {'accountLink': '/user/id/979119338',
#    'displayName': 'Isabelle N',
#    'realm': 'RT',
#    'userId': '979119338'}},
#  {'createDate': '2021-04-27T19:20:32.778Z',
#   'displayImageUrl': None,
#   'displayName': 'Wiz D',
#   'hasProfanity': False,
#   'hasSpoilers': False,
#   'isSuperReviewer': False,
#   'isVerified': False,
#   'rating': 'STAR_5',
#   'review': 'A masterpice with a heavy a realistic critic to the society.',
#   'score': 5,
#   'timeFromCreation': '4d ago',
#   'updateDate': '2021-04-27T19:20:34.150Z',
#   'user': {'accountLink': '/user/id/979105775',
#    'displayName': 'Wiz D',
#    'realm': 'RT',
#    'userId': '979105775'}},
#  {'createDate': '2021-04-26T14:35:36.281Z',
#   'displayImageUrl': None,
#   'displayName': None,
#   'hasProfanity': False,
#   'hasSpoilers': False,
#   'isSuperReviewer': False,
#   'isVerified': False,
#   'rating': 'STAR_5',
#   'review': 'Brilliantly compelling commentary on the ways in which the rich feed off the poor and vice versa - although only one side is doing so for survival. The disturbing climax illustrates vividly the great equalizing factor for all. Masterful storytelling that sticks with you. ',
#   'score': 5,
#   'timeFromCreation': '5d ago',
#   'updateDate': '2021-04-26T14:35:44.204Z',
#   'user': {'accountLink': None,
#    'displayName': None,
#    'realm': 'Flixster',
#    'userId': 'e9ae999b-b593-4b0d-ad4f-02d56ffc0e5e'}},
#  {'createDate': '2021-04-24T23:41:51.372Z',
#   'displayImageUrl': None,
#   'displayName': 'D D',
#   'hasProfanity': False,
#   'hasSpoilers': False,
#   'isSuperReviewer': False,
#   'isVerified': False,
#   'rating': 'STAR_5',
#   'review': "This film is unpredictable, creative, funny, suspenseful and the acting is fantastic. Best film I've seen in a long time.",
#   'score': 5,
#   'timeFromCreation': 'Apr 24, 2021',
#   'updateDate': '2021-04-24T23:41:52.161Z',
#   'user': {'accountLink': '/user/id/979115618',
#    'displayName': 'D D',
#    'realm': 'RT',
#    'userId': '979115618'}}]

# %%
# Getting the info I want
# Making a new list of dictionaries with that info:

parasite_reviews = []

for rev in reviews:
    rev_dict = {
        'date' : rev['timeFromCreation'],
        'text' : rev['review'],
        'score' : rev['score']
    }
    parasite_reviews.append(rev_dict)

# %%
len(parasite_reviews)
# Out:
# 4672

# %% [markdown]
# Pretty decent amount of reviews! It looks like we have a bit more for user reviews of _The Host_ (5,216) but 4,672 is pretty close. And this number might change after we filter out non-English reviews, which you can take a look at in the `lang_detect` notebook.
#
# Now let's look at the first several reviews in this list:

# %%
parasite_reviews[:10]
# Out:
# [{'date': '3h ago',
#   'score': 5,
#   'text': "Watch it!!!!!!! I don't need to say a word, just trust me."},
#  {'date': '3d ago',
#   'score': 5,
#   'text': 'unlike the justice league the snyder cut the parasite is not 4 hours long and actually good and balances its comedy, drama and horror elements with razor precision therefore it is pretentious therefore it is not kino'},
#  {'date': '3d ago',
#   'score': 5,
#   'text': "One of the best films I've ever seen in my life, couldn't have been executed better.\nBrilliant actors, amazing script, great twist, just marvelous!"},
#  {'date': '4d ago',
#   'score': 5,
#   'text': '100% fresh baby no puedes darle menos a esto'},
#  {'date': '4d ago',
#   'score': 5,
#   'text': "This movie is a masterpiece in all senses. Parasite portrays the intimate true about the social classes. The movement of characters show how the difference between classes in life occurs. The colors and the photography speak without using words. The script is amazing, the film is of elegant suspense that doesn't show itself and makes the audience scream Wow! every moment. I think is a good movie to explain the social issues in a decadent society, which only cares about not losing its position of power."},
#  {'date': '4d ago',
#   'score': 5,
#   'text': 'A masterpice with a heavy a realistic critic to the society.'},
#  {'date': '5d ago',
#   'score': 5,
#   'text': 'Brilliantly compelling commentary on the ways in which the rich feed off the poor and vice versa - although only one side is doing so for survival. The disturbing climax illustrates vividly the great equalizing factor for all. Masterful storytelling that sticks with you. '},
#  {'date': 'Apr 24, 2021',
#   'score': 5,
#   'text': "This film is unpredictable, creative, funny, suspenseful and the acting is fantastic. Best film I've seen in a long time."},
#  {'date': 'Apr 24, 2021',
#   'score': 5,
#   'text': 'An invigorating and engaging take on class divide as well as the meaning of family. This film seems to go through many genres, yet it does so seamlessly.'},
#  {'date': 'Apr 24, 2021',
#   'score': 5,
#   'text': 'This film begins with the image of a pile of socks drying near the narrow window of Ki-Taek\'s house. He lives on an "intermediate floor", a kind of basement whose view overlooks a trash can where a homeless person urinates. The four family members are constantly dirty, moving between cramped rooms as they search for a free Wi-Fi network in the neighborhood. The description of this family is grotesque, just as the bourgeois description of the Park family will be grotesque. The latter inhabit the spacious house created by a famous architect, where the four members are scattered around the rooms and get bored with all the technology and objects at their disposal. The two cores are identical opposites (father, mother, daughter and son), like the reflection of a mirror.\nDirector Bong Joon-ho moves on to a caricature view of the social classes, whose stratification is represented by the literal structure of the houses - see the rich man\'s house, the poor\'s middle floor and a basement, an even more precarious level that will play an important role in the plot. While the Park\'s wealth makes them naive and ignorant (no curiosity for the world around them due to the ease of their possessions), the protagonists\' poverty motivates trickery, the ability to create all possible tricks to ascend socially. It does not take long before families meet and the unemployed manage to infiltrate the wealthy house, one by one, gaining the trust of new employers. The notion of parasitism suggested by the title works perfectly to describe the central conflict.\nThe first half of the narrative is a delightful comic farce. The plans devised by father (Song Kang-ho), mother (Chang Hyae-jin), daughter (Park So-dam) and son (Choi Woo-sik) are as simple as they are hilarious, working only thanks to the Park\'s innocence. The director is not deprived of creating really exaggerated scenes, betting on physical humor and the blows of destiny that contribute to the success of the mission. The viewer needs to show a high degree of indulgence to believe in some of the twists and turns, as well as certain elements of suspense introduced along the way. Joon-ho is much more interested in the symbolic value of the actions and characters than in the verisimilitude of the plot, which becomes an allegorical fable of ants and cicadas, foxes and chickens.\nFortunately, as suspense sets in, Parasite takes the precaution of expanding the social scope and visiting other families in a situation as precarious as that of the protagonists. This is the time to reveal the different ways of dealing with difficulties, so that the parasitism of Ki-Taek and her family is not seen as the only possible way out. The flood scene proves to be particularly effective in affecting the lower floors while preserving the upper floors. Aesthetically, the project demonstrates the pragmatic elegance of the director, who never sacrifices understanding in the name of beauty. The filmmaker proves an excellent mastery of tones, directing the scribe, the touching drama and the dark suspense in different, yet organic and permeable ways.\nFinally, it is not surprising that the narrative leads to tragedy. The script sees violence as the only possible outcome for the clash between extreme poverty and ostentatious wealth, between the boss\'s hypocritical education (who even likes the employees, despite having a "subway smell") and the restrained aggressiveness of the employees. The film builds a time bomb, accentuating differences and social injustices until it explodes in a bloody climax. In this way, it allegorically represents the class struggle, the ideas of possession and appropriation in the contemporary era. It is commendable that the text dedicates a privileged space for cell phones, "gourmet balconies", the back rooms - so many elements representative of the times in which we live.\nWhen the son is faced with a serious problem, he tries to put himself in the place of the rich friend: "W ...

# %% [markdown]
# Saving out my list as a json file:

# %%
with open('../data/user_reviews/tomatoes_parasite_user.json','w', encoding='UTF-8') as out:
    out.write(json.dumps(parasite_reviews))

# %% [markdown]
# Loading in the data to make some initial observations about my data descriptives:

# %%
rt_parasite_user = json.load(open('../data/user_reviews/tomatoes_parasite_user.json'))

# %%
rt_parasite_user[:10]
# Out:
# [{'date': '3h ago',
#   'score': 5,
#   'text': "Watch it!!!!!!! I don't need to say a word, just trust me."},
#  {'date': '3d ago',
#   'score': 5,
#   'text': 'unlike the justice league the snyder cut the parasite is not 4 hours long and actually good and balances its comedy, drama and horror elements with razor precision therefore it is pretentious therefore it is not kino'},
#  {'date': '3d ago',
#   'score': 5,
#   'text': "One of the best films I've ever seen in my life, couldn't have been executed better.\nBrilliant actors, amazing script, great twist, just marvelous!"},
#  {'date': '4d ago',
#   'score': 5,
#   'text': '100% fresh baby no puedes darle menos a esto'},
#  {'date': '4d ago',
#   'score': 5,
#   'text': "This movie is a masterpiece in all senses. Parasite portrays the intimate true about the social classes. The movement of characters show how the difference between classes in life occurs. The colors and the photography speak without using words. The script is amazing, the film is of elegant suspense that doesn't show itself and makes the audience scream Wow! every moment. I think is a good movie to explain the social issues in a decadent society, which only cares about not losing its position of power."},
#  {'date': '4d ago',
#   'score': 5,
#   'text': 'A masterpice with a heavy a realistic critic to the society.'},
#  {'date': '5d ago',
#   'score': 5,
#   'text': 'Brilliantly compelling commentary on the ways in which the rich feed off the poor and vice versa - although only one side is doing so for survival. The disturbing climax illustrates vividly the great equalizing factor for all. Masterful storytelling that sticks with you. '},
#  {'date': 'Apr 24, 2021',
#   'score': 5,
#   'text': "This film is unpredictable, creative, funny, suspenseful and the acting is fantastic. Best film I've seen in a long time."},
#  {'date': 'Apr 24, 2021',
#   'score': 5,
#   'text': 'An invigorating and engaging take on class divide as well as the meaning of family. This film seems to go through many genres, yet it does so seamlessly.'},
#  {'date': 'Apr 24, 2021',
#   'score': 5,
#   'text': 'This film begins with the image of a pile of socks drying near the narrow window of Ki-Taek\'s house. He lives on an "intermediate floor", a kind of basement whose view overlooks a trash can where a homeless person urinates. The four family members are constantly dirty, moving between cramped rooms as they search for a free Wi-Fi network in the neighborhood. The description of this family is grotesque, just as the bourgeois description of the Park family will be grotesque. The latter inhabit the spacious house created by a famous architect, where the four members are scattered around the rooms and get bored with all the technology and objects at their disposal. The two cores are identical opposites (father, mother, daughter and son), like the reflection of a mirror.\nDirector Bong Joon-ho moves on to a caricature view of the social classes, whose stratification is represented by the literal structure of the houses - see the rich man\'s house, the poor\'s middle floor and a basement, an even more precarious level that will play an important role in the plot. While the Park\'s wealth makes them naive and ignorant (no curiosity for the world around them due to the ease of their possessions), the protagonists\' poverty motivates trickery, the ability to create all possible tricks to ascend socially. It does not take long before families meet and the unemployed manage to infiltrate the wealthy house, one by one, gaining the trust of new employers. The notion of parasitism suggested by the title works perfectly to describe the central conflict.\nThe first half of the narrative is a delightful comic farce. The plans devised by father (Song Kang-ho), mother (Chang Hyae-jin), daughter (Park So-dam) and son (Choi Woo-sik) are as simple as they are hilarious, working only thanks to the Park\'s innocence. The director is not deprived of creating really exaggerated scenes, betting on physical humor and the blows of destiny that contribute to the success of the mission. The viewer needs to show a high degree of indulgence to believe in some of the twists and turns, as well as certain elements of suspense introduced along the way. Joon-ho is much more interested in the symbolic value of the actions and characters than in the verisimilitude of the plot, which becomes an allegorical fable of ants and cicadas, foxes and chickens.\nFortunately, as suspense sets in, Parasite takes the precaution of expanding the social scope and visiting other families in a situation as precarious as that of the protagonists. This is the time to reveal the different ways of dealing with difficulties, so that the parasitism of Ki-Taek and her family is not seen as the only possible way out. The flood scene proves to be particularly effective in affecting the lower floors while preserving the upper floors. Aesthetically, the project demonstrates the pragmatic elegance of the director, who never sacrifices understanding in the name of beauty. The filmmaker proves an excellent mastery of tones, directing the scribe, the touching drama and the dark suspense in different, yet organic and permeable ways.\nFinally, it is not surprising that the narrative leads to tragedy. The script sees violence as the only possible outcome for the clash between extreme poverty and ostentatious wealth, between the boss\'s hypocritical education (who even likes the employees, despite having a "subway smell") and the restrained aggressiveness of the employees. The film builds a time bomb, accentuating differences and social injustices until it explodes in a bloody climax. In this way, it allegorically represents the class struggle, the ideas of possession and appropriation in the contemporary era. It is commendable that the text dedicates a privileged space for cell phones, "gourmet balconies", the back rooms - so many elements representative of the times in which we live.\nWhen the son is faced with a serious problem, he tries to put himself in the place of the rich friend: "W ...

# %% [markdown]
# One thing to note: it looks like some of the most recent reviews, which are shown at the top of the list in the code cell result above, have a different `date` format. This is because the information I extracted for my list is actually representing the time that has surpassed since the review was posted.
#
# So for example, I collected this data on May 1, 2021. As we can see, the very first dictionary in our list is a review that was posted on that same day, hence the `date` shows up as " 3 hr ago ". This is obviously not the format we want, so I will go ahead and manually change that in the json file.
#
# Now it will have the same format as the rest of this list:

# %%
rt_parasite_user = json.load(open('../data/user_reviews/tomatoes_parasite_user.json'))

# %%
rt_parasite_user[:10]
# Out:
# [{'date': 'May 1, 2021',
#   'score': 5,
#   'text': "Watch it!!!!!!! I don't need to say a word, just trust me."},
#  {'date': 'Apr 29, 2021',
#   'score': 5,
#   'text': 'unlike the justice league the snyder cut the parasite is not 4 hours long and actually good and balances its comedy, drama and horror elements with razor precision therefore it is pretentious therefore it is not kino'},
#  {'date': 'Apr 28, 2021',
#   'score': 5,
#   'text': "One of the best films I've ever seen in my life, couldn't have been executed better.\nBrilliant actors, amazing script, great twist, just marvelous!"},
#  {'date': 'Apr 28, 2021',
#   'score': 5,
#   'text': '100% fresh baby no puedes darle menos a esto'},
#  {'date': 'Apr 27, 2021',
#   'score': 5,
#   'text': "This movie is a masterpiece in all senses. Parasite portrays the intimate true about the social classes. The movement of characters show how the difference between classes in life occurs. The colors and the photography speak without using words. The script is amazing, the film is of elegant suspense that doesn't show itself and makes the audience scream Wow! every moment. I think is a good movie to explain the social issues in a decadent society, which only cares about not losing its position of power."},
#  {'date': 'Apr 27, 2021',
#   'score': 5,
#   'text': 'A masterpice with a heavy a realistic critic to the society.'},
#  {'date': 'Apr 26, 2021',
#   'score': 5,
#   'text': 'Brilliantly compelling commentary on the ways in which the rich feed off the poor and vice versa - although only one side is doing so for survival. The disturbing climax illustrates vividly the great equalizing factor for all. Masterful storytelling that sticks with you. '},
#  {'date': 'Apr 24, 2021',
#   'score': 5,
#   'text': "This film is unpredictable, creative, funny, suspenseful and the acting is fantastic. Best film I've seen in a long time."},
#  {'date': 'Apr 24, 2021',
#   'score': 5,
#   'text': 'An invigorating and engaging take on class divide as well as the meaning of family. This film seems to go through many genres, yet it does so seamlessly.'},
#  {'date': 'Apr 24, 2021',
#   'score': 5,
#   'text': 'This film begins with the image of a pile of socks drying near the narrow window of Ki-Taek\'s house. He lives on an "intermediate floor", a kind of basement whose view overlooks a trash can where a homeless person urinates. The four family members are constantly dirty, moving between cramped rooms as they search for a free Wi-Fi network in the neighborhood. The description of this family is grotesque, just as the bourgeois description of the Park family will be grotesque. The latter inhabit the spacious house created by a famous architect, where the four members are scattered around the rooms and get bored with all the technology and objects at their disposal. The two cores are identical opposites (father, mother, daughter and son), like the reflection of a mirror.\nDirector Bong Joon-ho moves on to a caricature view of the social classes, whose stratification is represented by the literal structure of the houses - see the rich man\'s house, the poor\'s middle floor and a basement, an even more precarious level that will play an important role in the plot. While the Park\'s wealth makes them naive and ignorant (no curiosity for the world around them due to the ease of their possessions), the protagonists\' poverty motivates trickery, the ability to create all possible tricks to ascend socially. It does not take long before families meet and the unemployed manage to infiltrate the wealthy house, one by one, gaining the trust of new employers. The notion of parasitism suggested by the title works perfectly to describe the central conflict.\nThe first half of the narrative is a delightful comic farce. The plans devised by father (Song Kang-ho), mother (Chang Hyae-jin), daughter (Park So-dam) and son (Choi Woo-sik) are as simple as they are hilarious, working only thanks to the Park\'s innocence. The director is not deprived of creating really exaggerated scenes, betting on physical humor and the blows of destiny that contribute to the success of the mission. The viewer needs to show a high degree of indulgence to believe in some of the twists and turns, as well as certain elements of suspense introduced along the way. Joon-ho is much more interested in the symbolic value of the actions and characters than in the verisimilitude of the plot, which becomes an allegorical fable of ants and cicadas, foxes and chickens.\nFortunately, as suspense sets in, Parasite takes the precaution of expanding the social scope and visiting other families in a situation as precarious as that of the protagonists. This is the time to reveal the different ways of dealing with difficulties, so that the parasitism of Ki-Taek and her family is not seen as the only possible way out. The flood scene proves to be particularly effective in affecting the lower floors while preserving the upper floors. Aesthetically, the project demonstrates the pragmatic elegance of the director, who never sacrifices understanding in the name of beauty. The filmmaker proves an excellent mastery of tones, directing the scribe, the touching drama and the dark suspense in different, yet organic and permeable ways.\nFinally, it is not surprising that the narrative leads to tragedy. The script sees violence as the only possible outcome for the clash between extreme poverty and ostentatious wealth, between the boss\'s hypocritical education (who even likes the employees, despite having a "subway smell") and the restrained aggressiveness of the employees. The film builds a time bomb, accentuating differences and social injustices until it explodes in a bloody climax. In this way, it allegorically represents the class struggle, the ideas of possession and appropriation in the contemporary era. It is commendable that the text dedicates a privileged space for cell phones, "gourmet balconies", the back rooms - so many elements representative of the times in which we live.\nWhen the son is faced with a serious problem, he tries to put himself in the place of the rich friend: "W ...

# %% [markdown]
# Great! Now the dates are all following the same format.
#
# ## Conclusion
#
# In this notebook, I went through the process of scraping, organizing, and extracting information from Rotten Tomatoes on user reviews of _Parasite_ . I was able to get 4,672 reviews, and now I'll move on to filtering out non-English reviews so that I can run my analyses. For this, please refer to the `lang_detect` notebook. And for the data analysis on these user reviews, refer to `analysis_user_tomatoes1` and `analysis_user_tomatoes2`!
#
# See you!
